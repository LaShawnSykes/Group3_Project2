# %%
# Initial imports
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
Mushroom_df = pd.read_csv("mushrooms_classification.csv")

# %%
Mushroom_df
# Out:
#       cap_shape cap_surface cap_color  bruises     odor gill_attachment  \
# 0     undefined      smooth     brown     True  pungent            free
# 1     undefined      smooth    yellow     True   almond            free
# 2          bell      smooth     white     True    anise            free
# 3     undefined       scaly     white     True  pungent            free
# 4     undefined      smooth      grey    False     none            free
# ...         ...         ...       ...      ...      ...             ...
# 8119    knobbed      smooth     brown    False     none        attached
# 8120  undefined      smooth     brown    False     none        attached
# 8121       flat      smooth     brown    False     none        attached
# 8122    knobbed       scaly     brown    False    fishy            free
# 8123  undefined      smooth     brown    False     none        attached
#
#      gill_spacing gill_size gill_color stalk_shape  ...  \
# ...

# %%
Mushroom_df.drop(columns=['cap_shape'], inplace=True)

# %%
Mushroom_df
# Out:
#      cap_surface cap_color  bruises     odor gill_attachment gill_spacing  \
# 0         smooth     brown     True  pungent            free        close
# 1         smooth    yellow     True   almond            free        close
# 2         smooth     white     True    anise            free        close
# 3          scaly     white     True  pungent            free        close
# 4         smooth      grey    False     none            free      crowded
# ...          ...       ...      ...      ...             ...          ...
# 8119      smooth     brown    False     none        attached        close
# 8120      smooth     brown    False     none        attached        close
# 8121      smooth     brown    False     none        attached        close
# 8122       scaly     brown    False    fishy            free        close
# 8123      smooth     brown    False     none        attached        close
#
#      gill_size gill_color stalk_shape stalk_root  ... stalk_color_above_ring  \
# ...

# %%
Mushroom_df_copy=Mushroom_df.copy()

# %%
Mushroom_df_copy
# Out:
#      cap_surface cap_color  bruises     odor gill_attachment gill_spacing  \
# 0         smooth     brown     True  pungent            free        close
# 1         smooth    yellow     True   almond            free        close
# 2         smooth     white     True    anise            free        close
# 3          scaly     white     True  pungent            free        close
# 4         smooth      grey    False     none            free      crowded
# ...          ...       ...      ...      ...             ...          ...
# 8119      smooth     brown    False     none        attached        close
# 8120      smooth     brown    False     none        attached        close
# 8121      smooth     brown    False     none        attached        close
# 8122       scaly     brown    False    fishy            free        close
# 8123      smooth     brown    False     none        attached        close
#
#      gill_size gill_color stalk_shape stalk_root  ... stalk_color_above_ring  \
# ...

# %%
Mushroom_df_copy.value_counts
# Out:
# <bound method DataFrame.value_counts of      cap_surface cap_color  bruises     odor gill_attachment gill_spacing  \
# 0         smooth     brown     True  pungent            free        close
# 1         smooth    yellow     True   almond            free        close
# 2         smooth     white     True    anise            free        close
# 3          scaly     white     True  pungent            free        close
# 4         smooth      grey    False     none            free      crowded
# ...          ...       ...      ...      ...             ...          ...
# 8119      smooth     brown    False     none        attached        close
# 8120      smooth     brown    False     none        attached        close
# 8121      smooth     brown    False     none        attached        close
# 8122       scaly     brown    False    fishy            free        close
# 8123      smooth     brown    False     none        attached        close
#
# ...

# %%
one_hot_mushroom_df_copy=pd.get_dummies(Mushroom_df_copy)

# %%
one_hot_mushroom_df_copy
# Out:
#       bruises  ring_number  poisonous  cap_surface_fibrous  \
# 0        True            1          1                False
# 1        True            1          0                False
# 2        True            1          0                False
# 3        True            1          1                False
# 4       False            1          0                False
# ...       ...          ...        ...                  ...
# 8119    False            1          0                False
# 8120    False            1          0                False
# 8121    False            1          0                False
# 8122    False            1          1                False
# 8123    False            1          0                False
#
#       cap_surface_grooves  cap_surface_scaly  cap_surface_smooth  \
# 0                   False              False                True
# 1                   False              False                True
# ...

# %%
#Save One Hot Encoded CSV
one_hot_mushroom_df_copy.to_csv('output.csv', index=False)

# %%
#Print original DataFrame
Mushroom_df
# Out:
#      cap_surface cap_color  bruises     odor gill_attachment gill_spacing  \
# 0         smooth     brown     True  pungent            free        close
# 1         smooth    yellow     True   almond            free        close
# 2         smooth     white     True    anise            free        close
# 3          scaly     white     True  pungent            free        close
# 4         smooth      grey    False     none            free      crowded
# ...          ...       ...      ...      ...             ...          ...
# 8119      smooth     brown    False     none        attached        close
# 8120      smooth     brown    False     none        attached        close
# 8121      smooth     brown    False     none        attached        close
# 8122       scaly     brown    False    fishy            free        close
# 8123      smooth     brown    False     none        attached        close
#
#      gill_size gill_color stalk_shape stalk_root  ... stalk_color_above_ring  \
# ...
